# %%
run efficient_frontier.py
# Out:
# [*********************100%***********************]  17 of 17 completed
# 2016-01-01
# Avg Annual Returns
# ADI     0.213096
# AMD     0.894709
# AMZN    0.357758
# BIIB    0.077943
# ISRG    0.285183
# JNJ     0.113446
# LRCX    0.359323
# PCG    -0.038466
# PTON    0.617073
# SCHW    0.096591
# SDC    -0.489960
# SLRX   -0.652617
# STAA    0.530925
# TM      0.024380
# TSLA    0.437004
# WORK   -0.219924
# XLNX    0.211045
# dtype: float64
# Min Variance Portfolio
#                 337517
# Returns       0.226226
# Volatility    0.210287
# Sharpe Ratio  1.075796
# ADI Weight    0.066568
# AMD Weight    0.016753
# AMZN Weight   0.088787
# BIIB Weight   0.101108
# ISRG Weight   0.155565
# JNJ Weight    0.160384
# LRCX Weight   0.012427
# PCG Weight    0.017172
# PTON Weight   0.116993
# SCHW Weight   0.032436
# SDC Weight    0.003930
# SLRX Weight   0.007974
# STAA Weight   0.022152
# TM Weight     0.135717
# TSLA Weight   0.004851
# WORK Weight   0.014879
# XLNX Weight   0.042305
# ...
